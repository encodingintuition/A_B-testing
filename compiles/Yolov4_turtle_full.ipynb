# %% [markdown]
# ## FUll yolov4 - 412x412 64 batch - subdiv=4

# %%
# FULL Model

# %% [markdown]
# ## Mount with your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Setup darknet environment

# %%
# check whether GPU is provided
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %% [markdown]
# ##Download Dark Net

# %%
# !ls
# Out:
# LICENSE  README.md

# %%
import os
assert os.getcwd()=='/content', 'Directory should be "/content" instead of "{}"'.format(os.getcwd())


# !git clone https://github.com/encodingintuition/darknet-yolov4-full.git
# %cd darknet-yolov4-full
# !make
# !chmod +x ./darknet
# Out:
# Cloning into 'darknet-yolov4-full'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# /content/darknet-yolov4-full
# make: *** No targets specified and no makefile found.  Stop.
# chmod: cannot access './darknet': No such file or directory

# %% [markdown]
# ## Weights

# %%
assert os.getcwd()=='/content/darknet-yolov4_full', 'Directory should be "/content/darknet-yolov4_full" instead of "{}"'.format(os.getcwd())
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %% [markdown]
# ## Dataset upload

# %%
# goes to the drive 

# %cd /content/drive/My Drive/
# copies files from drive

# %cp -av yolov4/datasets/data-in.zip /content/darknet-yolov4_full/
# move to colab folder

# %cd /content/darknet-yolov4_full
# unizip files

# !unzip data-in.zip 
# move files to data folder

# %cp -ar /content/darknet-yolov4_full/data-in/* /content/darknet-yolov4_full/data/

# %%
#check all is updated

# %ls /content/darknet-yolov4_full/data/
# Out:
# classes.names  obj/      obj.names  valid.txt
# labels/        obj.data  train.txt  yolov4.data

# %% [markdown]
# ## Visualize custom dataset examples (optional)

# %%
assert os.getcwd()=='/content/darknet-yolov4_full', 'Directory should be "/content/darknet-yolov4_full" instead of "{}"'.format(os.getcwd())

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import glob

def read_label(image_path):
  file_name = image_path.replace('.jpg', '.txt')
  with open(file_name, 'rt') as file:
    print(os.path.basename(file_name) + ': \n' + file.read())

image_path = glob.glob("data/obj/*.jpg")
fig = plt.figure(figsize=(12,8))
cols = 2
rows = 2
grid = gridspec.GridSpec(nrows=rows, ncols=cols, figure=fig)
for i in range(cols*rows):
  fig.add_subplot(grid[i])
  image=plt.imread(image_path[i])
  plt.title(os.path.basename(image_path[i]))
  plt.axis(False)
  plt.imshow(image)
  read_label(image_path[i])

plt.savefig("dataset_examples.jpg", dpi=300)

# %% [markdown]
# ## Link to gDrive

# %%
assert os.getcwd()=='/content/darknet-yolov4_full', 'Directory should be "/content/darknet-yolov4_full" instead of "{}"'.format(os.getcwd())

# delete backup folder from our 
# !rm /content/darknet-yolov4_full/backup -r

# create Symlinks so we can save trained weight in our Google Drive
# create folder YOLOv4_weight/back in your Drive to store trained weights
#
#       
#
# !ln -s /content/drive/'My Drive'/YOLOv4_weight/backup /content/darknet-yolov4_full

# %% [markdown]
# ### Set consel to not disconnect

# %%
"""

function ConnectButton(){
    console.log("Connect pushed"); 
    document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click() 
}
setInterval(ConnectButton,60000);


"""

# %%
# %ls
# Out:
# 3rdparty/                data/                   net_cam_v3.sh*
# backup@                  data-in/                obj/
# build.ps1*               data-in.zip             README.md
# build.sh*                image_yolov2.sh*        results/
# cfg/                     image_yolov3.sh*        scripts/
# cmake/                   include/                src/
# CMakeLists.txt*          json_mjpeg_streams.sh*  uselib*
# darknet*                 libdarknet.so*          video_v2.sh*
# DarknetConfig.cmake.in*  LICENSE*                video_yolov3.sh*
# darknet.py*              __MACOSX/               yolov4-tiny.conv.29
# darknet_video.py*        Makefile*               yolov4_tiny_train_best.weights

# %% [markdown]
# ## Training

# %%
# Checks drive

assert os.getcwd()=='/content/darknet-yolov4_full', 'Directory should be "/darknet-yolov4_full" instead of "{}"'.format(os.getcwd())

# %%
# %%capture
# !./darknet detector train data/yolov4.data cfg/yolov4_custom_train.cfg yolov4.conv.137 -dont_show -map
#If you get CUDA out of memory adjust subdivisions above!
#adjust max batches down for shorter training above

# %% [markdown]
# ## Visualize training result

# %%
assert os.getcwd()=='/content/darknet-yolov4_full', 'Directory should be "/content/darknet-yolov4_full" instead of "{}"'.format(os.getcwd())

# Plotting training result after 2000 epochs
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
train_result = plt.imread("chart.png")
plt.axis(False)
plt.imshow(train_result)

# %%
# show labels of dataset
assert os.getcwd()=='/content/darknet-yolov4_full', 'Directory should be "/content/darknet-yolov4_full" instead of "{}"'.format(os.getcwd())

# !cat data/classes.names
# Out:
# foward
# back
# left
# right
# input
# plus
# three
# seven

# %%
# best model training

# !./darknet detector map data/yolov4.data cfg/yolov4_custom_train.cfg /content/drive/'My Drive'/yolov4_weight/backup/yolov4_tiny_train_last.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
# ...

# %%
# !./darknet detector map data/yolov4.data cfg/yolov4_custom_train.cfg /content/drive/'My Drive'/yolov4_weight/backup/yolov4_tiny_train_6000.weights
